# %%
import os
import nltk
import nltk.corpus
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
import re

# %%
nltk.download('brown')
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\karth\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\brown.zip.
# True

# %%
from nltk.corpus import brown
data = brown.words()
listdata = list(data)
len(data)
# Out:
# 1161192

# %%
fdist = FreqDist()

# %%
for word in data:
    fdist[word.lower()]+=1

fdist
# Out:
# FreqDist({'the': 69971, ',': 58334, '.': 49346, 'of': 36412, 'and': 28853, 'to': 26158, 'a': 23195, 'in': 21337, 'that': 10594, 'is': 10109, ...})

# %%
punctuation = re.compile(r'[-.?!,`\'\":;()|0-9]')
post_pun = []
for words in data:
    word = punctuation.sub("", words)
    if len(word)>0:
        post_pun.append(word)

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\karth\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
stop_words = set(stopwords.words('english'))

# %%
filtered_words = [word for word in post_pun if word.lower() not in stop_words]

# %%
def generate_ngrams(tokens):
    ngrams = []
    for i in range(len(tokens) - 5 + 1):
        ngram = tokens[i:i + 5]
        ngrams.append(ngram)
    return ngrams

# %%
context = generate_ngrams(filtered_words)

# %%
context
# Out:
# [['Fulton', 'County', 'Grand', 'Jury', 'said'],
#  ['County', 'Grand', 'Jury', 'said', 'Friday'],
#  ['Grand', 'Jury', 'said', 'Friday', 'investigation'],
#  ['Jury', 'said', 'Friday', 'investigation', 'Atlantas'],
#  ['said', 'Friday', 'investigation', 'Atlantas', 'recent'],
#  ['Friday', 'investigation', 'Atlantas', 'recent', 'primary'],
#  ['investigation', 'Atlantas', 'recent', 'primary', 'election'],
#  ['Atlantas', 'recent', 'primary', 'election', 'produced'],
#  ['recent', 'primary', 'election', 'produced', 'evidence'],
#  ['primary', 'election', 'produced', 'evidence', 'irregularities'],
#  ['election', 'produced', 'evidence', 'irregularities', 'took'],
#  ['produced', 'evidence', 'irregularities', 'took', 'place'],
#  ['evidence', 'irregularities', 'took', 'place', 'jury'],
#  ['irregularities', 'took', 'place', 'jury', 'said'],
#  ['took', 'place', 'jury', 'said', 'termend'],
#  ['place', 'jury', 'said', 'termend', 'presentments'],
#  ['jury', 'said', 'termend', 'presentments', 'City'],
#  ['said', 'termend', 'presentments', 'City', 'Executive'],
#  ['termend', 'presentments', 'City', 'Executive', 'Committee'],
#  ['presentments', 'City', 'Executive', 'Committee', 'overall'],
#  ['City', 'Executive', 'Committee', 'overall', 'charge'],
#  ['Executive', 'Committee', 'overall', 'charge', 'election'],
#  ['Committee', 'overall', 'charge', 'election', 'deserves'],
#  ['overall', 'charge', 'election', 'deserves', 'praise'],
#  ['charge', 'election', 'deserves', 'praise', 'thanks'],
#  ['election', 'deserves', 'praise', 'thanks', 'City'],
#  ['deserves', 'praise', 'thanks', 'City', 'Atlanta'],
#  ['praise', 'thanks', 'City', 'Atlanta', 'manner'],
#  ['thanks', 'City', 'Atlanta', 'manner', 'election'],
#  ['City', 'Atlanta', 'manner', 'election', 'conducted'],
#  ['Atlanta', 'manner', 'election', 'conducted', 'SeptemberOctober'],
#  ['manner', 'election', 'conducted', 'SeptemberOctober', 'term'],
#  ['election', 'conducted', 'SeptemberOctober', 'term', 'jury'],
#  ['conducted', 'SeptemberOctober', 'term', 'jury', 'charged'],
#  ['SeptemberOctober', 'term', 'jury', 'charged', 'Fulton'],
#  ['term', 'jury', 'charged', 'Fulton', 'Superior'],
#  ['jury', 'charged', 'Fulton', 'Superior', 'Court'],
#  ['charged', 'Fulton', 'Superior', 'Court', 'Judge'],
#  ['Fulton', 'Superior', 'Court', 'Judge', 'Durwood'],
#  ['Superior', 'Court', 'Judge', 'Durwood', 'Pye'],
#  ['Court', 'Judge', 'Durwood', 'Pye', 'investigate'],
#  ['Judge', 'Durwood', 'Pye', 'investigate', 'reports'],
#  ['Durwood', 'Pye', 'investigate', 'reports', 'possible'],
#  ['Pye', 'investigate', 'reports', 'possible', 'irregularities'],
#  ['investigate', 'reports', 'possible', 'irregularities', 'hardfought'],
#  ['reports', 'possible', 'irregularities', 'hardfought', 'primary'],
#  ['possible', 'irregularities', 'hardfought', 'primary', 'Mayornominate'],
#  ['irregularities', 'hardfought', 'primary', 'Mayornominate', 'Ivan'],
#  ['hardfought', 'primary', 'Mayornominate', 'Ivan', 'Allen'],
#  ['primary', 'Mayornominate', 'Ivan', 'Allen', 'Jr'],
#  ['Mayornominate', 'Ivan', 'Allen', 'Jr', 'relative'],
#  ['Ivan', 'Allen', 'Jr', 'relative', 'handful'],
#  ['Allen', 'Jr', 'relative', 'handful', 'reports'],
#  ['Jr', 'relative', 'handful', 'reports', 'received'],
#  ['relative', 'handful', 'reports', 'received', 'jury'],
#  ['handful', 'reports', 'received', 'jury', 'said'],
#  ['reports', 'received', 'jury', 'said', 'considering'],
#  ['received', 'jury', 'said', 'considering', 'widespread'],
#  ['jury', 'said', 'considering', 'widespread', 'interest'],
#  ['said', 'considering', 'widespread', 'interest', 'election'],
#  ['considering', 'widespread', 'interest', 'election', 'number'],
#  ['widespread', 'interest', 'election', 'number', 'voters'],
#  ['interest', 'election', 'number', 'voters', 'size'],
#  ['election', 'number', 'voters', 'size', 'city'],
#  ['number', 'voters', 'size', 'city', 'jury'],
#  ['voters', 'size', 'city', 'jury', 'said'],
#  ['size', 'city', 'jury', 'said', 'find'],
#  ['city', 'jury', 'said', 'find', 'many'],
#  ['jury', 'said', 'find', 'many', 'Georgias'],
#  ['said', 'find', 'many', 'Georgias', 'registration'],
#  ['find', 'many', 'Georgias', 'registration', 'election'],
#  ['many', 'Georgias', 'registration', 'election', 'laws'],
#  ['Georgias', 'registration', 'election', 'laws', 'outmoded'],
#  ['registration', 'election', 'laws', 'outmoded', 'inadequate'],
#  ['election', 'laws', 'outmoded', 'inadequate', 'often'],
#  ['laws', 'outmoded', 'inadequate', 'often', 'ambiguous'],
#  ['outmoded', 'inadequate', 'often', 'ambiguous', 'recommended'],
#  ['inadequate', 'often', 'ambiguous', 'recommended', 'Fulton'],
#  ['often', 'ambiguous', 'recommended', 'Fulton', 'legislators'],
#  ['ambiguous', 'recommended', 'Fulton', 'legislators', 'act'],
#  ['recommended', 'Fulton', 'legislators', 'act', 'laws'],
#  ['Fulton', 'legislators', 'act', 'laws', 'studied'],
#  ['legislators', 'act', 'laws', 'studied', 'revised'],
#  ['act', 'laws', 'studied', 'revised', 'end'],
#  ['laws', 'studied', 'revised', 'end', 'modernizing'],
#  ['studied', 'revised', 'end', 'modernizing', 'improving'],
#  ['revised', 'end', 'modernizing', 'improving', 'grand'],
#  ['end', 'modernizing', 'improving', 'grand', 'jury'],
#  ['modernizing', 'improving', 'grand', 'jury', 'commented'],
#  ['improving', 'grand', 'jury', 'commented', 'number'],
#  ['grand', 'jury', 'commented', 'number', 'topics'],
#  ['jury', 'commented', 'number', 'topics', 'among'],
#  ['commented', 'number', 'topics', 'among', 'Atlanta'],
#  ['number', 'topics', 'among', 'Atlanta', 'Fulton'],
#  ['topics', 'among', 'Atlanta', 'Fulton', 'County'],
#  ['among', 'Atlanta', 'Fulton', 'County', 'purchasing'],
#  ['Atlanta', 'Fulton', 'County', 'purchasing', 'departments'],
#  ['Fulton', 'County', 'purchasing', 'departments', 'said'],
#  ['County', 'purchasing', 'departments', 'said', 'well'],
#  ['purchasing', 'departments', 'said', 'well', 'operated'],
#  ['departments', 'said', 'well', 'operated', 'follow'],
#  ['said', 'well', 'operated', 'follow', 'generally'],
#  ['well', 'operated', 'follow', 'generally', 'accepted'],
#  ['operated', 'follow', 'generally', 'accepted', 'practices'],
#  ['follow', 'generally', 'accepted', 'practices', 'inure'],
#  ['generally', 'accepted', 'practices', 'inure', 'best'],
#  ['accepted', 'practices', 'inure', 'best', 'interest'],
#  ['practices', 'inure', 'best', 'interest', 'governments'],
#  ['inure', 'best', 'interest', 'governments', 'Merger'],
#  ['best', 'interest', 'governments', 'Merger', 'proposed'],
#  ['interest', 'governments', 'Merger', 'proposed', 'However'],
#  ['governments', 'Merger', 'proposed', 'However', 'jury'],
#  ['Merger', 'proposed', 'However', 'jury', 'said'],
#  ['proposed', 'However', 'jury', 'said', 'believes'],
#  ['However', 'jury', 'said', 'believes', 'two'],
#  ['jury', 'said', 'believes', 'two', 'offices'],
#  ['said', 'believes', 'two', 'offices', 'combined'],
#  ['believes', 'two', 'offices', 'combined', 'achieve'],
#  ['two', 'offices', 'combined', 'achieve', 'greater'],
#  ['offices', 'combined', 'achieve', 'greater', 'efficiency'],
#  ['combined', 'achieve', 'greater', 'efficiency', 'reduce'],
#  ['achieve', 'greater', 'efficiency', 'reduce', 'cost'],
#  ['greater', 'efficiency', 'reduce', 'cost', 'administration'],
#  ['efficiency', 'reduce', 'cost', 'administration', 'City'],
#  ['reduce', 'cost', 'administration', 'City', 'Purchasing'],
#  ['cost', 'administration', 'City', 'Purchasing', 'Department'],
#  ['administration', 'City', 'Purchasing', 'Department', 'jury'],
#  ['City', 'Purchasing', 'Department', 'jury', 'said'],
#  ['Purchasing', 'Department', 'jury', 'said', 'lacking'],
#  ['Department', 'jury', 'said', 'lacking', 'experienced'],
#  ['jury', 'said', 'lacking', 'experienced', 'clerical'],
#  ['said', 'lacking', 'experienced', 'clerical', 'personnel'],
#  ['lacking', 'experienced', 'clerical', 'personnel', 'result'],
#  ['experienced', 'clerical', 'personnel', 'result', 'city'],
#  ['clerical', 'personnel', 'result', 'city', 'personnel'],
#  ['personnel', 'result', 'city', 'personnel', 'policies'],
#  ['result', 'city', 'personnel', 'policies', 'urged'],
#  ['city', 'personnel', 'policies', 'urged', 'city'],
#  ['personnel', 'policies', 'urged', 'city', 'take'],
#  ['policies', 'urged', 'city', 'take', 'steps'],
#  ['urged', 'city', 'take', 'steps', 'remedy'],
#  ['city', 'take', 'steps', 'remedy', 'problem'],
#  ['take', 'steps', 'remedy', 'problem', 'Implementation'],
#  ['steps', 'remedy', 'problem', 'Implementation', 'Georgias'],
#  ['remedy', 'problem', 'Implementation', 'Georgias', 'automobile'],
#  ['problem', 'Implementation', 'Georgias', 'automobile', 'title'],
#  ['Implementation', 'Georgias', 'automobile', 'title', 'law'],
#  ['Georgias', 'automobile', 'title', 'law', 'also'],
#  ['automobile', 'title', 'law', 'also', 'recommended'],
#  ['title', 'law', 'also', 'recommended', 'outgoing'],
#  ['law', 'also', 'recommended', 'outgoing', 'jury'],
#  ['also', 'recommended', 'outgoing', 'jury', 'urged'],
#  ['recommended', 'outgoing', 'jury', 'urged', 'next'],
#  ['outgoing', 'jury', 'urged', 'next', 'Legislature'],
#  ['jury', 'urged', 'next', 'Legislature', 'provide'],
#  ['urged', 'next', 'Legislature', 'provide', 'enabling'],
#  ['next', 'Legislature', 'provide', 'enabling', 'funds'],
#  ['Legislature', 'provide', 'enabling', 'funds', 'reset'],
#  ['provide', 'enabling', 'funds', 'reset', 'effective'],
#  ['enabling', 'funds', 'reset', 'effective', 'date'],
#  ['funds', 'reset', 'effective', 'date', 'orderly'],
#  ['reset', 'effective', 'date', 'orderly', 'implementation'],
#  ['effective', 'date', 'orderly', 'implementation', 'law'],
#  ['date', 'orderly', 'implementation', 'law', 'may'],
#  ['orderly', 'implementation', 'law', 'may', 'effected'],
#  ['implementation', 'law', 'may', 'effected', 'grand'],
#  ['law', 'may', 'effected', 'grand', 'jury'],
#  ['may', 'effected', 'grand', 'jury', 'took'],
#  ['effected', 'grand', 'jury', 'took', 'swipe'],
#  ['grand', 'jury', 'took', 'swipe', 'State'],
#  ['jury', 'took', 'swipe', 'State', 'Welfare'],
#  ['took', 'swipe', 'State', 'Welfare', 'Departments'],
#  ['swipe', 'State', 'Welfare', 'Departments', 'handling'],
#  ['State', 'Welfare', 'Departments', 'handling', 'federal'],
#  ['Welfare', 'Departments', 'handling', 'federal', 'funds'],
#  ['Departments', 'handling', 'federal', 'funds', 'granted'],
#  ['handling', 'federal', 'funds', 'granted', 'child'],
#  ['federal', 'funds', 'granted', 'child', 'welfare'],
#  ['funds', 'granted', 'child', 'welfare', 'services'],
#  ['granted', 'child', 'welfare', 'services', 'foster'],
#  ['child', 'welfare', 'services', 'foster', 'homes'],
#  ['welfare', 'services', 'foster', 'homes', 'one'],
#  ['services', 'foster', 'homes', 'one', 'major'],
#  ['foster', 'homes', 'one', 'major', 'items'],
#  ['homes', 'one', 'major', 'items', 'Fulton'],
#  ['one', 'major', 'items', 'Fulton', 'County'],
#  ['major', 'items', 'Fulton', 'County', 'general'],
#  ['items', 'Fulton', 'County', 'general', 'assistance'],
#  ['Fulton', 'County', 'general', 'assistance', 'program'],
#  ['County', 'general', 'assistance', 'program', 'jury'],
#  ['general', 'assistance', 'program', 'jury', 'said'],
#  ['assistance', 'program', 'jury', 'said', 'State'],
#  ['program', 'jury', 'said', 'State', 'Welfare'],
#  ['jury', 'said', 'State', 'Welfare', 'Department'],
#  ['said', 'State', 'Welfare', 'Department', 'seen'],
#  ['State', 'Welfare', 'Department', 'seen', 'fit'],
#  ['Welfare', 'Department', 'seen', 'fit', 'distribute'],
#  ['Department', 'seen', 'fit', 'distribute', 'funds'],
#  ['seen', 'fit', 'distribute', 'funds', 'welfare'],
#  ['fit', 'distribute', 'funds', 'welfare', 'departments'],
#  ['distribute', 'funds', 'welfare', 'departments', 'counties'],
#  ['funds', 'welfare', 'departments', 'counties', 'state'],
#  ['welfare', 'departments', 'counties', 'state', 'exception'],
#  ['departments', 'counties', 'state', 'exception', 'Fulton'],
#  ['counties', 'state', 'exception', 'Fulton', 'County'],
#  ['state', 'exception', 'Fulton', 'County', 'receives'],
#  ['exception', 'Fulton', 'County', 'receives', 'none'],
#  ['Fulton', 'County', 'receives', 'none', 'money'],
#  ['County', 'receives', 'none', 'money', 'jurors'],
#  ['receives', 'none', 'money', 'jurors', 'said'],
#  ['none', 'money', 'jurors', 'said', 'realize'],
#  ['money', 'jurors', 'said', 'realize', 'proportionate'],
#  ['jurors', 'said', 'realize', 'proportionate', 'distribution'],
#  ['said', 'realize', 'proportionate', 'distribution', 'funds'],
#  ['realize', 'proportionate', 'distribution', 'funds', 'might'],
#  ['proportionate', 'distribution', 'funds', 'might', 'disable'],
#  ['distribution', 'funds', 'might', 'disable', 'program'],
#  ['funds', 'might', 'disable', 'program', 'less'],
#  ['might', 'disable', 'program', 'less', 'populous'],
#  ['disable', 'program', 'less', 'populous', 'counties'],
#  ['program', 'less', 'populous', 'counties', 'Nevertheless'],
#  ['less', 'populous', 'counties', 'Nevertheless', 'feel'],
#  ['populous', 'counties', 'Nevertheless', 'feel', 'future'],
#  ['counties', 'Nevertheless', 'feel', 'future', 'Fulton'],
#  ['Nevertheless', 'feel', 'future', 'Fulton', 'County'],
#  ['feel', 'future', 'Fulton', 'County', 'receive'],
#  ['future', 'Fulton', 'County', 'receive', 'portion'],
#  ['Fulton', 'County', 'receive', 'portion', 'available'],
#  ['County', 'receive', 'portion', 'available', 'funds'],
#  ['receive', 'portion', 'available', 'funds', 'jurors'],
#  ['portion', 'available', 'funds', 'jurors', 'said'],
#  ['available', 'funds', 'jurors', 'said', 'Failure'],
#  ['funds', 'jurors', 'said', 'Failure', 'continue'],
#  ['jurors', 'said', 'Failure', 'continue', 'place'],
#  ['said', 'Failure', 'continue', 'place', 'disproportionate'],
#  ['Failure', 'continue', 'place', 'disproportionate', 'burden'],
#  ['continue', 'place', 'disproportionate', 'burden', 'Fulton'],
#  ['place', 'disproportionate', 'burden', 'Fulton', 'taxpayers'],
#  ['disproportionate', 'burden', 'Fulton', 'taxpayers', 'jury'],
#  ['burden', 'Fulton', 'taxpayers', 'jury', 'also'],
#  ['Fulton', 'taxpayers', 'jury', 'also', 'commented'],
#  ['taxpayers', 'jury', 'also', 'commented', 'Fulton'],
#  ['jury', 'also', 'commented', 'Fulton', 'ordinarys'],
#  ['also', 'commented', 'Fulton', 'ordinarys', 'court'],
#  ['commented', 'Fulton', 'ordinarys', 'court', 'fire'],
#  ['Fulton', 'ordinarys', 'court', 'fire', 'practices'],
#  ['ordinarys', 'court', 'fire', 'practices', 'appointment'],
#  ['court', 'fire', 'practices', 'appointment', 'appraisers'],
#  ['fire', 'practices', 'appointment', 'appraisers', 'guardians'],
#  ['practices', 'appointment', 'appraisers', 'guardians', 'administrators'],
#  ['appointment', 'appraisers', 'guardians', 'administrators', 'awarding'],
#  ['appraisers', 'guardians', 'administrators', 'awarding', 'fees'],
#  ['guardians', 'administrators', 'awarding', 'fees', 'compensation'],
#  ['administrators', 'awarding', 'fees', 'compensation', 'Wards'],
#  ['awarding', 'fees', 'compensation', 'Wards', 'protected'],
#  ['fees', 'compensation', 'Wards', 'protected', 'jury'],
#  ['compensation', 'Wards', 'protected', 'jury', 'said'],
#  ['Wards', 'protected', 'jury', 'said', 'found'],
#  ['protected', 'jury', 'said', 'found', 'court'],
#  ['jury', 'said', 'found', 'court', 'incorporated'],
#  ['said', 'found', 'court', 'incorporated', 'operating'],
#  ['found', 'court', 'incorporated', 'operating', 'procedures'],
#  ['court', 'incorporated', 'operating', 'procedures', 'recommendations'],
#  ['incorporated', 'operating', 'procedures', 'recommendations', 'two'],
#  ['operating', 'procedures', 'recommendations', 'two', 'previous'],
#  ['procedures', 'recommendations', 'two', 'previous', 'grand'],
#  ['recommendations', 'two', 'previous', 'grand', 'juries'],
#  ['two', 'previous', 'grand', 'juries', 'Atlanta'],
#  ['previous', 'grand', 'juries', 'Atlanta', 'Bar'],
#  ['grand', 'juries', 'Atlanta', 'Bar', 'Association'],
#  ['juries', 'Atlanta', 'Bar', 'Association', 'interim'],
#  ['Atlanta', 'Bar', 'Association', 'interim', 'citizens'],
#  ['Bar', 'Association', 'interim', 'citizens', 'committee'],
#  ['Association', 'interim', 'citizens', 'committee', 'actions'],
#  ['interim', 'citizens', 'committee', 'actions', 'serve'],
#  ['citizens', 'committee', 'actions', 'serve', 'protect'],
#  ['committee', 'actions', 'serve', 'protect', 'fact'],
#  ['actions', 'serve', 'protect', 'fact', 'effect'],
#  ['serve', 'protect', 'fact', 'effect', 'courts'],
#  ['protect', 'fact', 'effect', 'courts', 'wards'],
#  ['fact', 'effect', 'courts', 'wards', 'undue'],
#  ['effect', 'courts', 'wards', 'undue', 'costs'],
#  ['courts', 'wards', 'undue', 'costs', 'appointed'],
#  ['wards', 'undue', 'costs', 'appointed', 'elected'],
#  ['undue', 'costs', 'appointed', 'elected', 'servants'],
#  ['costs', 'appointed', 'elected', 'servants', 'unmeritorious'],
#  ['appointed', 'elected', 'servants', 'unmeritorious', 'criticisms'],
#  ['elected', 'servants', 'unmeritorious', 'criticisms', 'jury'],
#  ['servants', 'unmeritorious', 'criticisms', 'jury', 'said'],
#  ['unmeritorious', 'criticisms', 'jury', 'said', 'Regarding'],
#  ['criticisms', 'jury', 'said', 'Regarding', 'Atlantas'],
#  ['jury', 'said', 'Regarding', 'Atlantas', 'new'],
#  ['said', 'Regarding', 'Atlantas', 'new', 'multimilliondollar'],
#  ['Regarding', 'Atlantas', 'new', 'multimilliondollar', 'airport'],
#  ['Atlantas', 'new', 'multimilliondollar', 'airport', 'jury'],
#  ['new', 'multimilliondollar', 'airport', 'jury', 'recommended'],
#  ['multimilliondollar', 'airport', 'jury', 'recommended', 'new'],
#  ['airport', 'jury', 'recommended', 'new', 'management'],
#  ['jury', 'recommended', 'new', 'management', 'takes'],
#  ['recommended', 'new', 'management', 'takes', 'charge'],
#  ['new', 'management', 'takes', 'charge', 'Jan'],
#  ['management', 'takes', 'charge', 'Jan', 'airport'],
#  ['takes', 'charge', 'Jan', 'airport', 'operated'],
#  ['charge', 'Jan', 'airport', 'operated', 'manner'],
#  ['Jan', 'airport', 'operated', 'manner', 'eliminate'],
#  ['airport', 'operated', 'manner', 'eliminate', 'political'],
#  ['operated', 'manner', 'eliminate', 'political', 'influences'],
#  ['manner', 'eliminate', 'political', 'influences', 'jury'],
#  ['eliminate', 'political', 'influences', 'jury', 'elaborate'],
#  ['political', 'influences', 'jury', 'elaborate', 'added'],
#  ['influences', 'jury', 'elaborate', 'added', 'periodic'],
#  ['jury', 'elaborate', 'added', 'periodic', 'surveillance'],
#  ['elaborate', 'added', 'periodic', 'surveillance', 'pricing'],
#  ['added', 'periodic', 'surveillance', 'pricing', 'practices'],
#  ['periodic', 'surveillance', 'pricing', 'practices', 'concessionaires'],
#  ['surveillance', 'pricing', 'practices', 'concessionaires', 'purpose'],
#  ['pricing', 'practices', 'concessionaires', 'purpose', 'keeping'],
#  ['practices', 'concessionaires', 'purpose', 'keeping', 'prices'],
#  ['concessionaires', 'purpose', 'keeping', 'prices', 'reasonable'],
#  ['purpose', 'keeping', 'prices', 'reasonable', 'Ask'],
#  ['keeping', 'prices', 'reasonable', 'Ask', 'jail'],
#  ['prices', 'reasonable', 'Ask', 'jail', 'deputies'],
#  ['reasonable', 'Ask', 'jail', 'deputies', 'matters'],
#  ['Ask', 'jail', 'deputies', 'matters', 'jury'],
#  ['jail', 'deputies', 'matters', 'jury', 'recommended'],
#  ['deputies', 'matters', 'jury', 'recommended', 'Four'],
#  ['matters', 'jury', 'recommended', 'Four', 'additional'],
#  ['jury', 'recommended', 'Four', 'additional', 'deputies'],
#  ['recommended', 'Four', 'additional', 'deputies', 'employed'],
#  ['Four', 'additional', 'deputies', 'employed', 'Fulton'],
#  ['additional', 'deputies', 'employed', 'Fulton', 'County'],
#  ['deputies', 'employed', 'Fulton', 'County', 'Jail'],
#  ['employed', 'Fulton', 'County', 'Jail', 'doctor'],
#  ['Fulton', 'County', 'Jail', 'doctor', 'medical'],
#  ['County', 'Jail', 'doctor', 'medical', 'intern'],
#  ['Jail', 'doctor', 'medical', 'intern', 'extern'],
#  ['doctor', 'medical', 'intern', 'extern', 'employed'],
#  ['medical', 'intern', 'extern', 'employed', 'night'],
#  ['intern', 'extern', 'employed', 'night', 'weekend'],
#  ['extern', 'employed', 'night', 'weekend', 'duty'],
#  ['employed', 'night', 'weekend', 'duty', 'jail'],
#  ['night', 'weekend', 'duty', 'jail', 'Fulton'],
#  ['weekend', 'duty', 'jail', 'Fulton', 'legislators'],
#  ['duty', 'jail', 'Fulton', 'legislators', 'work'],
#  ['jail', 'Fulton', 'legislators', 'work', 'city'],
#  ['Fulton', 'legislators', 'work', 'city', 'officials'],
#  ['legislators', 'work', 'city', 'officials', 'pass'],
#  ['work', 'city', 'officials', 'pass', 'enabling'],
#  ['city', 'officials', 'pass', 'enabling', 'legislation'],
#  ['officials', 'pass', 'enabling', 'legislation', 'permit'],
#  ['pass', 'enabling', 'legislation', 'permit', 'establishment'],
#  ['enabling', 'legislation', 'permit', 'establishment', 'fair'],
#  ['legislation', 'permit', 'establishment', 'fair', 'equitable'],
#  ['permit', 'establishment', 'fair', 'equitable', 'pension'],
#  ['establishment', 'fair', 'equitable', 'pension', 'plan'],
#  ['fair', 'equitable', 'pension', 'plan', 'city'],
#  ['equitable', 'pension', 'plan', 'city', 'employes'],
#  ['pension', 'plan', 'city', 'employes', 'jury'],
#  ['plan', 'city', 'employes', 'jury', 'praised'],
#  ['city', 'employes', 'jury', 'praised', 'administration'],
#  ['employes', 'jury', 'praised', 'administration', 'operation'],
#  ['jury', 'praised', 'administration', 'operation', 'Atlanta'],
#  ['praised', 'administration', 'operation', 'Atlanta', 'Police'],
#  ['administration', 'operation', 'Atlanta', 'Police', 'Department'],
#  ['operation', 'Atlanta', 'Police', 'Department', 'Fulton'],
#  ['Atlanta', 'Police', 'Department', 'Fulton', 'Tax'],
#  ['Police', 'Department', 'Fulton', 'Tax', 'Commissioners'],
#  ['Department', 'Fulton', 'Tax', 'Commissioners', 'Office'],
#  ['Fulton', 'Tax', 'Commissioners', 'Office', 'Bellwood'],
#  ['Tax', 'Commissioners', 'Office', 'Bellwood', 'Alpharetta'],
#  ['Commissioners', 'Office', 'Bellwood', 'Alpharetta', 'prison'],
#  ['Office', 'Bellwood', 'Alpharetta', 'prison', 'farms'],
#  ['Bellwood', 'Alpharetta', 'prison', 'farms', 'Grady'],
#  ['Alpharetta', 'prison', 'farms', 'Grady', 'Hospital'],
#  ['prison', 'farms', 'Grady', 'Hospital', 'Fulton'],
#  ['farms', 'Grady', 'Hospital', 'Fulton', 'Health'],
#  ['Grady', 'Hospital', 'Fulton', 'Health', 'Department'],
#  ['Hospital', 'Fulton', 'Health', 'Department', 'Mayor'],
#  ['Fulton', 'Health', 'Department', 'Mayor', 'William'],
#  ['Health', 'Department', 'Mayor', 'William', 'B'],
#  ['Department', 'Mayor', 'William', 'B', 'Hartsfield'],
#  ['Mayor', 'William', 'B', 'Hartsfield', 'filed'],
#  ['William', 'B', 'Hartsfield', 'filed', 'suit'],
#  ['B', 'Hartsfield', 'filed', 'suit', 'divorce'],
#  ['Hartsfield', 'filed', 'suit', 'divorce', 'wife'],
#  ['filed', 'suit', 'divorce', 'wife', 'Pearl'],
#  ['suit', 'divorce', 'wife', 'Pearl', 'Williams'],
#  ['divorce', 'wife', 'Pearl', 'Williams', 'Hartsfield'],
#  ['wife', 'Pearl', 'Williams', 'Hartsfield', 'Fulton'],
#  ['Pearl', 'Williams', 'Hartsfield', 'Fulton', 'Superior'],
#  ['Williams', 'Hartsfield', 'Fulton', 'Superior', 'Court'],
#  ['Hartsfield', 'Fulton', 'Superior', 'Court', 'Friday'],
#  ['Fulton', 'Superior', 'Court', 'Friday', 'petition'],
#  ['Superior', 'Court', 'Friday', 'petition', 'charged'],
#  ['Court', 'Friday', 'petition', 'charged', 'mental'],
#  ['Friday', 'petition', 'charged', 'mental', 'cruelty'],
#  ['petition', 'charged', 'mental', 'cruelty', 'couple'],
#  ['charged', 'mental', 'cruelty', 'couple', 'married'],
#  ['mental', 'cruelty', 'couple', 'married', 'Aug'],
#  ['cruelty', 'couple', 'married', 'Aug', 'son'],
#  ['couple', 'married', 'Aug', 'son', 'William'],
#  ['married', 'Aug', 'son', 'William', 'Berry'],
#  ['Aug', 'son', 'William', 'Berry', 'Jr'],
#  ['son', 'William', 'Berry', 'Jr', 'daughter'],
#  ['William', 'Berry', 'Jr', 'daughter', 'Mrs'],
#  ['Berry', 'Jr', 'daughter', 'Mrs', 'J'],
#  ['Jr', 'daughter', 'Mrs', 'J', 'Cheshire'],
#  ['daughter', 'Mrs', 'J', 'Cheshire', 'Griffin'],
#  ['Mrs', 'J', 'Cheshire', 'Griffin', 'Attorneys'],
#  ['J', 'Cheshire', 'Griffin', 'Attorneys', 'mayor'],
#  ['Cheshire', 'Griffin', 'Attorneys', 'mayor', 'said'],
#  ['Griffin', 'Attorneys', 'mayor', 'said', 'amicable'],
#  ['Attorneys', 'mayor', 'said', 'amicable', 'property'],
#  ['mayor', 'said', 'amicable', 'property', 'settlement'],
#  ['said', 'amicable', 'property', 'settlement', 'agreed'],
#  ['amicable', 'property', 'settlement', 'agreed', 'upon'],
#  ['property', 'settlement', 'agreed', 'upon', 'petition'],
#  ['settlement', 'agreed', 'upon', 'petition', 'listed'],
#  ['agreed', 'upon', 'petition', 'listed', 'mayors'],
#  ['upon', 'petition', 'listed', 'mayors', 'occupation'],
#  ['petition', 'listed', 'mayors', 'occupation', 'attorney'],
#  ['listed', 'mayors', 'occupation', 'attorney', 'age'],
#  ['mayors', 'occupation', 'attorney', 'age', 'listed'],
#  ['occupation', 'attorney', 'age', 'listed', 'wifes'],
#  ['attorney', 'age', 'listed', 'wifes', 'age'],
#  ['age', 'listed', 'wifes', 'age', 'place'],
#  ['listed', 'wifes', 'age', 'place', 'birth'],
#  ['wifes', 'age', 'place', 'birth', 'Opelika'],
#  ['age', 'place', 'birth', 'Opelika', 'Ala'],
#  ['place', 'birth', 'Opelika', 'Ala', 'petition'],
#  ['birth', 'Opelika', 'Ala', 'petition', 'said'],
#  ['Opelika', 'Ala', 'petition', 'said', 'couple'],
#  ['Ala', 'petition', 'said', 'couple', 'lived'],
#  ['petition', 'said', 'couple', 'lived', 'together'],
#  ['said', 'couple', 'lived', 'together', 'man'],
#  ['couple', 'lived', 'together', 'man', 'wife'],
#  ['lived', 'together', 'man', 'wife', 'year'],
#  ['together', 'man', 'wife', 'year', 'Hartsfield'],
#  ['man', 'wife', 'year', 'Hartsfield', 'home'],
#  ['wife', 'year', 'Hartsfield', 'home', 'E'],
#  ['year', 'Hartsfield', 'home', 'E', 'Pelham'],
#  ['Hartsfield', 'home', 'E', 'Pelham', 'Rd'],
#  ['home', 'E', 'Pelham', 'Rd', 'Aj'],
#  ['E', 'Pelham', 'Rd', 'Aj', 'Henry'],
#  ['Pelham', 'Rd', 'Aj', 'Henry', 'L'],
#  ['Rd', 'Aj', 'Henry', 'L', 'Bowden'],
#  ['Aj', 'Henry', 'L', 'Bowden', 'listed'],
#  ['Henry', 'L', 'Bowden', 'listed', 'petition'],
#  ['L', 'Bowden', 'listed', 'petition', 'mayors'],
#  ['Bowden', 'listed', 'petition', 'mayors', 'attorney'],
#  ['listed', 'petition', 'mayors', 'attorney', 'Hartsfield'],
#  ['petition', 'mayors', 'attorney', 'Hartsfield', 'mayor'],
#  ['mayors', 'attorney', 'Hartsfield', 'mayor', 'Atlanta'],
#  ['attorney', 'Hartsfield', 'mayor', 'Atlanta', 'exception'],
#  ['Hartsfield', 'mayor', 'Atlanta', 'exception', 'one'],
#  ['mayor', 'Atlanta', 'exception', 'one', 'brief'],
#  ['Atlanta', 'exception', 'one', 'brief', 'interlude'],
#  ['exception', 'one', 'brief', 'interlude', 'since'],
#  ['one', 'brief', 'interlude', 'since', 'political'],
#  ['brief', 'interlude', 'since', 'political', 'career'],
#  ['interlude', 'since', 'political', 'career', 'goes'],
#  ['since', 'political', 'career', 'goes', 'back'],
#  ['political', 'career', 'goes', 'back', 'election'],
#  ['career', 'goes', 'back', 'election', 'city'],
#  ['goes', 'back', 'election', 'city', 'council'],
#  ['back', 'election', 'city', 'council', 'mayors'],
#  ['election', 'city', 'council', 'mayors', 'present'],
#  ['city', 'council', 'mayors', 'present', 'term'],
#  ['council', 'mayors', 'present', 'term', 'office'],
#  ['mayors', 'present', 'term', 'office', 'expires'],
#  ['present', 'term', 'office', 'expires', 'Jan'],
#  ['term', 'office', 'expires', 'Jan', 'succeeded'],
#  ['office', 'expires', 'Jan', 'succeeded', 'Ivan'],
#  ['expires', 'Jan', 'succeeded', 'Ivan', 'Allen'],
#  ['Jan', 'succeeded', 'Ivan', 'Allen', 'Jr'],
#  ['succeeded', 'Ivan', 'Allen', 'Jr', 'became'],
#  ['Ivan', 'Allen', 'Jr', 'became', 'candidate'],
#  ['Allen', 'Jr', 'became', 'candidate', 'Sept'],
#  ['Jr', 'became', 'candidate', 'Sept', 'primary'],
#  ['became', 'candidate', 'Sept', 'primary', 'Mayor'],
#  ['candidate', 'Sept', 'primary', 'Mayor', 'Hartsfield'],
#  ['Sept', 'primary', 'Mayor', 'Hartsfield', 'announced'],
#  ['primary', 'Mayor', 'Hartsfield', 'announced', 'would'],
#  ['Mayor', 'Hartsfield', 'announced', 'would', 'run'],
#  ['Hartsfield', 'announced', 'would', 'run', 'reelection'],
#  ['announced', 'would', 'run', 'reelection', 'Georgia'],
#  ['would', 'run', 'reelection', 'Georgia', 'Republicans'],
#  ['run', 'reelection', 'Georgia', 'Republicans', 'getting'],
#  ['reelection', 'Georgia', 'Republicans', 'getting', 'strong'],
#  ['Georgia', 'Republicans', 'getting', 'strong', 'encouragement'],
#  ['Republicans', 'getting', 'strong', 'encouragement', 'enter'],
#  ['getting', 'strong', 'encouragement', 'enter', 'candidate'],
#  ['strong', 'encouragement', 'enter', 'candidate', 'governors'],
#  ['encouragement', 'enter', 'candidate', 'governors', 'race'],
#  ['enter', 'candidate', 'governors', 'race', 'top'],
#  ['candidate', 'governors', 'race', 'top', 'official'],
#  ['governors', 'race', 'top', 'official', 'said'],
#  ['race', 'top', 'official', 'said', 'Wednesday'],
#  ['top', 'official', 'said', 'Wednesday', 'Robert'],
#  ['official', 'said', 'Wednesday', 'Robert', 'Snodgrass'],
#  ['said', 'Wednesday', 'Robert', 'Snodgrass', 'state'],
#  ['Wednesday', 'Robert', 'Snodgrass', 'state', 'GOP'],
#  ['Robert', 'Snodgrass', 'state', 'GOP', 'chairman'],
#  ['Snodgrass', 'state', 'GOP', 'chairman', 'said'],
#  ['state', 'GOP', 'chairman', 'said', 'meeting'],
#  ['GOP', 'chairman', 'said', 'meeting', 'held'],
#  ['chairman', 'said', 'meeting', 'held', 'Tuesday'],
#  ['said', 'meeting', 'held', 'Tuesday', 'night'],
#  ['meeting', 'held', 'Tuesday', 'night', 'Blue'],
#  ['held', 'Tuesday', 'night', 'Blue', 'Ridge'],
#  ['Tuesday', 'night', 'Blue', 'Ridge', 'brought'],
#  ['night', 'Blue', 'Ridge', 'brought', 'enthusiastic'],
#  ['Blue', 'Ridge', 'brought', 'enthusiastic', 'responses'],
#  ['Ridge', 'brought', 'enthusiastic', 'responses', 'audience'],
#  ['brought', 'enthusiastic', 'responses', 'audience', 'State'],
#  ['enthusiastic', 'responses', 'audience', 'State', 'Party'],
#  ['responses', 'audience', 'State', 'Party', 'Chairman'],
#  ['audience', 'State', 'Party', 'Chairman', 'James'],
#  ['State', 'Party', 'Chairman', 'James', 'W'],
#  ['Party', 'Chairman', 'James', 'W', 'Dorsey'],
#  ['Chairman', 'James', 'W', 'Dorsey', 'added'],
#  ['James', 'W', 'Dorsey', 'added', 'enthusiasm'],
#  ['W', 'Dorsey', 'added', 'enthusiasm', 'picking'],
#  ['Dorsey', 'added', 'enthusiasm', 'picking', 'state'],
#  ['added', 'enthusiasm', 'picking', 'state', 'rally'],
#  ['enthusiasm', 'picking', 'state', 'rally', 'held'],
#  ['picking', 'state', 'rally', 'held', 'Sept'],
#  ['state', 'rally', 'held', 'Sept', 'Savannah'],
#  ['rally', 'held', 'Sept', 'Savannah', 'newly'],
#  ['held', 'Sept', 'Savannah', 'newly', 'elected'],
#  ['Sept', 'Savannah', 'newly', 'elected', 'Texas'],
#  ['Savannah', 'newly', 'elected', 'Texas', 'Sen'],
#  ['newly', 'elected', 'Texas', 'Sen', 'John'],
#  ['elected', 'Texas', 'Sen', 'John', 'Tower'],
#  ['Texas', 'Sen', 'John', 'Tower', 'featured'],
#  ['Sen', 'John', 'Tower', 'featured', 'speaker'],
#  ['John', 'Tower', 'featured', 'speaker', 'Blue'],
#  ['Tower', 'featured', 'speaker', 'Blue', 'Ridge'],
#  ['featured', 'speaker', 'Blue', 'Ridge', 'meeting'],
#  ['speaker', 'Blue', 'Ridge', 'meeting', 'audience'],
#  ['Blue', 'Ridge', 'meeting', 'audience', 'warned'],
#  ['Ridge', 'meeting', 'audience', 'warned', 'entering'],
#  ['meeting', 'audience', 'warned', 'entering', 'candidate'],
#  ['audience', 'warned', 'entering', 'candidate', 'governor'],
#  ['warned', 'entering', 'candidate', 'governor', 'would'],
#  ['entering', 'candidate', 'governor', 'would', 'force'],
#  ['candidate', 'governor', 'would', 'force', 'take'],
#  ['governor', 'would', 'force', 'take', 'petitions'],
#  ['would', 'force', 'take', 'petitions', 'voting'],
#  ['force', 'take', 'petitions', 'voting', 'precincts'],
#  ['take', 'petitions', 'voting', 'precincts', 'obtain'],
#  ['petitions', 'voting', 'precincts', 'obtain', 'signatures'],
#  ['voting', 'precincts', 'obtain', 'signatures', 'registered'],
#  ['precincts', 'obtain', 'signatures', 'registered', 'voters'],
#  ['obtain', 'signatures', 'registered', 'voters', 'Despite'],
#  ['signatures', 'registered', 'voters', 'Despite', 'warning'],
#  ['registered', 'voters', 'Despite', 'warning', 'unanimous'],
#  ['voters', 'Despite', 'warning', 'unanimous', 'vote'],
#  ['Despite', 'warning', 'unanimous', 'vote', 'enter'],
#  ['warning', 'unanimous', 'vote', 'enter', 'candidate'],
#  ['unanimous', 'vote', 'enter', 'candidate', 'according'],
#  ['vote', 'enter', 'candidate', 'according', 'Republicans'],
#  ['enter', 'candidate', 'according', 'Republicans', 'attended'],
#  ['candidate', 'according', 'Republicans', 'attended', 'crowd'],
#  ['according', 'Republicans', 'attended', 'crowd', 'asked'],
#  ['Republicans', 'attended', 'crowd', 'asked', 'whether'],
#  ['attended', 'crowd', 'asked', 'whether', 'wanted'],
#  ['crowd', 'asked', 'whether', 'wanted', 'wait'],
#  ['asked', 'whether', 'wanted', 'wait', 'one'],
#  ['whether', 'wanted', 'wait', 'one', 'term'],
#  ['wanted', 'wait', 'one', 'term', 'make'],
#  ['wait', 'one', 'term', 'make', 'race'],
#  ['one', 'term', 'make', 'race', 'voted'],
#  ['term', 'make', 'race', 'voted', 'dissents'],
#  ['make', 'race', 'voted', 'dissents', 'largest'],
#  ['race', 'voted', 'dissents', 'largest', 'hurdle'],
#  ['voted', 'dissents', 'largest', 'hurdle', 'Republicans'],
#  ['dissents', 'largest', 'hurdle', 'Republicans', 'would'],
#  ['largest', 'hurdle', 'Republicans', 'would', 'face'],
#  ['hurdle', 'Republicans', 'would', 'face', 'state'],
#  ['Republicans', 'would', 'face', 'state', 'law'],
#  ['would', 'face', 'state', 'law', 'says'],
#  ['face', 'state', 'law', 'says', 'making'],
#  ['state', 'law', 'says', 'making', 'first'],
#  ['law', 'says', 'making', 'first', 'race'],
#  ['says', 'making', 'first', 'race', 'one'],
#  ['making', 'first', 'race', 'one', 'two'],
#  ['first', 'race', 'one', 'two', 'alternative'],
#  ['race', 'one', 'two', 'alternative', 'courses'],
#  ['one', 'two', 'alternative', 'courses', 'must'],
#  ['two', 'alternative', 'courses', 'must', 'taken'],
#  ['alternative', 'courses', 'must', 'taken', 'Five'],
#  ['courses', 'must', 'taken', 'Five', 'per'],
#  ['must', 'taken', 'Five', 'per', 'cent'],
#  ['taken', 'Five', 'per', 'cent', 'voters'],
#  ['Five', 'per', 'cent', 'voters', 'county'],
#  ['per', 'cent', 'voters', 'county', 'must'],
#  ['cent', 'voters', 'county', 'must', 'sign'],
#  ['voters', 'county', 'must', 'sign', 'petitions'],
#  ['county', 'must', 'sign', 'petitions', 'requesting'],
#  ['must', 'sign', 'petitions', 'requesting', 'Republicans'],
#  ['sign', 'petitions', 'requesting', 'Republicans', 'allowed'],
#  ['petitions', 'requesting', 'Republicans', 'allowed', 'place'],
#  ['requesting', 'Republicans', 'allowed', 'place', 'names'],
#  ['Republicans', 'allowed', 'place', 'names', 'candidates'],
#  ['allowed', 'place', 'names', 'candidates', 'general'],
#  ['place', 'names', 'candidates', 'general', 'election'],
#  ['names', 'candidates', 'general', 'election', 'ballot'],
#  ['candidates', 'general', 'election', 'ballot', 'Republicans'],
#  ['general', 'election', 'ballot', 'Republicans', 'must'],
#  ['election', 'ballot', 'Republicans', 'must', 'hold'],
#  ['ballot', 'Republicans', 'must', 'hold', 'primary'],
#  ['Republicans', 'must', 'hold', 'primary', 'county'],
#  ['must', 'hold', 'primary', 'county', 'unit'],
#  ['hold', 'primary', 'county', 'unit', 'system'],
#  ['primary', 'county', 'unit', 'system', 'system'],
#  ['county', 'unit', 'system', 'system', 'party'],
#  ['unit', 'system', 'system', 'party', 'opposes'],
#  ['system', 'system', 'party', 'opposes', 'platform'],
#  ['system', 'party', 'opposes', 'platform', 'Sam'],
#  ['party', 'opposes', 'platform', 'Sam', 'Caldwell'],
#  ['opposes', 'platform', 'Sam', 'Caldwell', 'State'],
#  ['platform', 'Sam', 'Caldwell', 'State', 'Highway'],
#  ['Sam', 'Caldwell', 'State', 'Highway', 'Department'],
#  ['Caldwell', 'State', 'Highway', 'Department', 'public'],
#  ['State', 'Highway', 'Department', 'public', 'relations'],
#  ['Highway', 'Department', 'public', 'relations', 'director'],
#  ['Department', 'public', 'relations', 'director', 'resigned'],
#  ['public', 'relations', 'director', 'resigned', 'Tuesday'],
#  ['relations', 'director', 'resigned', 'Tuesday', 'work'],
#  ['director', 'resigned', 'Tuesday', 'work', 'Lt'],
#  ['resigned', 'Tuesday', 'work', 'Lt', 'Gov'],
#  ['Tuesday', 'work', 'Lt', 'Gov', 'Garland'],
#  ['work', 'Lt', 'Gov', 'Garland', 'Byrds'],
#  ['Lt', 'Gov', 'Garland', 'Byrds', 'campaign'],
#  ['Gov', 'Garland', 'Byrds', 'campaign', 'Caldwells'],
#  ['Garland', 'Byrds', 'campaign', 'Caldwells', 'resignation'],
#  ['Byrds', 'campaign', 'Caldwells', 'resignation', 'expected'],
#  ['campaign', 'Caldwells', 'resignation', 'expected', 'time'],
#  ['Caldwells', 'resignation', 'expected', 'time', 'succeeded'],
#  ['resignation', 'expected', 'time', 'succeeded', 'Rob'],
#  ['expected', 'time', 'succeeded', 'Rob', 'Ledford'],
#  ['time', 'succeeded', 'Rob', 'Ledford', 'Gainesville'],
#  ['succeeded', 'Rob', 'Ledford', 'Gainesville', 'assistant'],
#  ['Rob', 'Ledford', 'Gainesville', 'assistant', 'three'],
#  ['Ledford', 'Gainesville', 'assistant', 'three', 'years'],
#  ['Gainesville', 'assistant', 'three', 'years', 'gubernatorial'],
#  ['assistant', 'three', 'years', 'gubernatorial', 'campaign'],
#  ['three', 'years', 'gubernatorial', 'campaign', 'starts'],
#  ['years', 'gubernatorial', 'campaign', 'starts', 'Caldwell'],
#  ['gubernatorial', 'campaign', 'starts', 'Caldwell', 'expected'],
#  ['campaign', 'starts', 'Caldwell', 'expected', 'become'],
#  ['starts', 'Caldwell', 'expected', 'become', 'campaign'],
#  ['Caldwell', 'expected', 'become', 'campaign', 'coordinator'],
#  ['expected', 'become', 'campaign', 'coordinator', 'Byrd'],
#  ['become', 'campaign', 'coordinator', 'Byrd', 'Georgia'],
#  ['campaign', 'coordinator', 'Byrd', 'Georgia', 'Legislature'],
#  ['coordinator', 'Byrd', 'Georgia', 'Legislature', 'wind'],
#  ['Byrd', 'Georgia', 'Legislature', 'wind', 'session'],
#  ['Georgia', 'Legislature', 'wind', 'session', 'Monday'],
#  ['Legislature', 'wind', 'session', 'Monday', 'head'],
#  ['wind', 'session', 'Monday', 'head', 'home'],
#  ['session', 'Monday', 'head', 'home', 'highway'],
#  ['Monday', 'head', 'home', 'highway', 'bond'],
#  ['head', 'home', 'highway', 'bond', 'money'],
#  ['home', 'highway', 'bond', 'money', 'approved'],
#  ['highway', 'bond', 'money', 'approved', 'follow'],
#  ['bond', 'money', 'approved', 'follow', 'shortly'],
#  ['money', 'approved', 'follow', 'shortly', 'adjournment'],
#  ['approved', 'follow', 'shortly', 'adjournment', 'Monday'],
#  ['follow', 'shortly', 'adjournment', 'Monday', 'afternoon'],
#  ['shortly', 'adjournment', 'Monday', 'afternoon', 'Senate'],
#  ['adjournment', 'Monday', 'afternoon', 'Senate', 'expected'],
#  ['Monday', 'afternoon', 'Senate', 'expected', 'approve'],
#  ['afternoon', 'Senate', 'expected', 'approve', 'study'],
#  ['Senate', 'expected', 'approve', 'study', 'number'],
#  ['expected', 'approve', 'study', 'number', 'legislators'],
#  ['approve', 'study', 'number', 'legislators', 'allotted'],
#  ['study', 'number', 'legislators', 'allotted', 'rural'],
#  ['number', 'legislators', 'allotted', 'rural', 'urban'],
#  ['legislators', 'allotted', 'rural', 'urban', 'areas'],
#  ['allotted', 'rural', 'urban', 'areas', 'determine'],
#  ['rural', 'urban', 'areas', 'determine', 'adjustments'],
#  ['urban', 'areas', 'determine', 'adjustments', 'made'],
#  ['areas', 'determine', 'adjustments', 'made', 'Gov'],
#  ['determine', 'adjustments', 'made', 'Gov', 'Vandiver'],
#  ['adjustments', 'made', 'Gov', 'Vandiver', 'expected'],
#  ['made', 'Gov', 'Vandiver', 'expected', 'make'],
#  ['Gov', 'Vandiver', 'expected', 'make', 'traditional'],
#  ['Vandiver', 'expected', 'make', 'traditional', 'visit'],
#  ['expected', 'make', 'traditional', 'visit', 'chambers'],
#  ['make', 'traditional', 'visit', 'chambers', 'work'],
#  ['traditional', 'visit', 'chambers', 'work', 'toward'],
#  ['visit', 'chambers', 'work', 'toward', 'adjournment'],
#  ['chambers', 'work', 'toward', 'adjournment', 'Vandiver'],
#  ['work', 'toward', 'adjournment', 'Vandiver', 'likely'],
#  ['toward', 'adjournment', 'Vandiver', 'likely', 'mention'],
#  ['adjournment', 'Vandiver', 'likely', 'mention', '$'],
#  ['Vandiver', 'likely', 'mention', '$', 'million'],
#  ['likely', 'mention', '$', 'million', 'highway'],
#  ['mention', '$', 'million', 'highway', 'bond'],
#  ['$', 'million', 'highway', 'bond', 'issue'],
#  ['million', 'highway', 'bond', 'issue', 'approved'],
#  ['highway', 'bond', 'issue', 'approved', 'earlier'],
#  ['bond', 'issue', 'approved', 'earlier', 'session'],
#  ['issue', 'approved', 'earlier', 'session', 'first'],
#  ['approved', 'earlier', 'session', 'first', 'priority'],
#  ['earlier', 'session', 'first', 'priority', 'item'],
#  ['session', 'first', 'priority', 'item', 'Construction'],
#  ['first', 'priority', 'item', 'Construction', 'bonds'],
#  ['priority', 'item', 'Construction', 'bonds', 'Meanwhile'],
#  ['item', 'Construction', 'bonds', 'Meanwhile', 'learned'],
#  ['Construction', 'bonds', 'Meanwhile', 'learned', 'State'],
#  ['bonds', 'Meanwhile', 'learned', 'State', 'Highway'],
#  ['Meanwhile', 'learned', 'State', 'Highway', 'Department'],
#  ['learned', 'State', 'Highway', 'Department', 'near'],
#  ['State', 'Highway', 'Department', 'near', 'ready'],
#  ['Highway', 'Department', 'near', 'ready', 'issue'],
#  ['Department', 'near', 'ready', 'issue', 'first'],
#  ['near', 'ready', 'issue', 'first', '$'],
#  ['ready', 'issue', 'first', '$', 'million'],
#  ['issue', 'first', '$', 'million', 'worth'],
#  ['first', '$', 'million', 'worth', 'highway'],
#  ['$', 'million', 'worth', 'highway', 'reconstruction'],
#  ['million', 'worth', 'highway', 'reconstruction', 'bonds'],
#  ['worth', 'highway', 'reconstruction', 'bonds', 'bond'],
#  ['highway', 'reconstruction', 'bonds', 'bond', 'issue'],
#  ['reconstruction', 'bonds', 'bond', 'issue', 'go'],
#  ['bonds', 'bond', 'issue', 'go', 'state'],
#  ['bond', 'issue', 'go', 'state', 'courts'],
#  ['issue', 'go', 'state', 'courts', 'friendly'],
#  ['go', 'state', 'courts', 'friendly', 'test'],
#  ['state', 'courts', 'friendly', 'test', 'suit'],
#  ['courts', 'friendly', 'test', 'suit', 'test'],
#  ['friendly', 'test', 'suit', 'test', 'validity'],
#  ['test', 'suit', 'test', 'validity', 'act'],
#  ['suit', 'test', 'validity', 'act', 'sales'],
#  ['test', 'validity', 'act', 'sales', 'begin'],
#  ['validity', 'act', 'sales', 'begin', 'contracts'],
#  ['act', 'sales', 'begin', 'contracts', 'let'],
#  ['sales', 'begin', 'contracts', 'let', 'repair'],
#  ['begin', 'contracts', 'let', 'repair', 'work'],
#  ['contracts', 'let', 'repair', 'work', 'Georgias'],
#  ['let', 'repair', 'work', 'Georgias', 'heavily'],
#  ['repair', 'work', 'Georgias', 'heavily', 'traveled'],
#  ['work', 'Georgias', 'heavily', 'traveled', 'highways'],
#  ['Georgias', 'heavily', 'traveled', 'highways', 'Highway'],
#  ['heavily', 'traveled', 'highways', 'Highway', 'Department'],
#  ['traveled', 'highways', 'Highway', 'Department', 'source'],
#  ['highways', 'Highway', 'Department', 'source', 'said'],
#  ['Highway', 'Department', 'source', 'said', 'also'],
#  ['Department', 'source', 'said', 'also', 'plan'],
#  ['source', 'said', 'also', 'plan', 'issue'],
#  ['said', 'also', 'plan', 'issue', '$'],
#  ['also', 'plan', 'issue', '$', 'million'],
#  ['plan', 'issue', '$', 'million', '$'],
#  ['issue', '$', 'million', '$', 'million'],
#  ['$', 'million', '$', 'million', 'worth'],
#  ['million', '$', 'million', 'worth', 'Rural'],
#  ['$', 'million', 'worth', 'Rural', 'Roads'],
#  ['million', 'worth', 'Rural', 'Roads', 'Authority'],
#  ['worth', 'Rural', 'Roads', 'Authority', 'bonds'],
#  ['Rural', 'Roads', 'Authority', 'bonds', 'rural'],
#  ['Roads', 'Authority', 'bonds', 'rural', 'road'],
#  ['Authority', 'bonds', 'rural', 'road', 'construction'],
#  ['bonds', 'rural', 'road', 'construction', 'work'],
#  ['rural', 'road', 'construction', 'work', 'revolving'],
#  ['road', 'construction', 'work', 'revolving', 'fund'],
#  ['construction', 'work', 'revolving', 'fund', 'department'],
#  ['work', 'revolving', 'fund', 'department', 'apparently'],
#  ['revolving', 'fund', 'department', 'apparently', 'intends'],
#  ['fund', 'department', 'apparently', 'intends', 'make'],
#  ['department', 'apparently', 'intends', 'make', 'Rural'],
#  ['apparently', 'intends', 'make', 'Rural', 'Roads'],
#  ['intends', 'make', 'Rural', 'Roads', 'Authority'],
#  ['make', 'Rural', 'Roads', 'Authority', 'revolving'],
#  ['Rural', 'Roads', 'Authority', 'revolving', 'fund'],
#  ['Roads', 'Authority', 'revolving', 'fund', 'new'],
#  ['Authority', 'revolving', 'fund', 'new', 'bonds'],
#  ['revolving', 'fund', 'new', 'bonds', 'would'],
#  ['fund', 'new', 'bonds', 'would', 'issued'],
#  ['new', 'bonds', 'would', 'issued', 'every'],
#  ['bonds', 'would', 'issued', 'every', 'time'],
#  ['would', 'issued', 'every', 'time', 'portion'],
#  ['issued', 'every', 'time', 'portion', 'old'],
#  ['every', 'time', 'portion', 'old', 'ones'],
#  ['time', 'portion', 'old', 'ones', 'paid'],
#  ['portion', 'old', 'ones', 'paid', 'tax'],
#  ['old', 'ones', 'paid', 'tax', 'authorities'],
#  ['ones', 'paid', 'tax', 'authorities', 'Vandiver'],
#  ['paid', 'tax', 'authorities', 'Vandiver', 'opened'],
#  ['tax', 'authorities', 'Vandiver', 'opened', 'race'],
#  ['authorities', 'Vandiver', 'opened', 'race', 'governor'],
#  ['Vandiver', 'opened', 'race', 'governor', 'battle'],
#  ['opened', 'race', 'governor', 'battle', 'Legislature'],
#  ['race', 'governor', 'battle', 'Legislature', 'issuance'],
#  ['governor', 'battle', 'Legislature', 'issuance', '$'],
#  ['battle', 'Legislature', 'issuance', '$', 'million'],
#  ['Legislature', 'issuance', '$', 'million', 'worth'],
#  ['issuance', '$', 'million', 'worth', 'additional'],
#  ['$', 'million', 'worth', 'additional', 'rural'],
#  ['million', 'worth', 'additional', 'rural', 'roads'],
#  ['worth', 'additional', 'rural', 'roads', 'bonds'],
#  ['additional', 'rural', 'roads', 'bonds', 'proposed'],
#  ['rural', 'roads', 'bonds', 'proposed', 'Gov'],
#  ['roads', 'bonds', 'proposed', 'Gov', 'Marvin'],
#  ['bonds', 'proposed', 'Gov', 'Marvin', 'Griffin'],
#  ['proposed', 'Gov', 'Marvin', 'Griffin', 'Highway'],
#  ['Gov', 'Marvin', 'Griffin', 'Highway', 'Department'],
#  ['Marvin', 'Griffin', 'Highway', 'Department', 'source'],
#  ['Griffin', 'Highway', 'Department', 'source', 'told'],
#  ['Highway', 'Department', 'source', 'told', 'Constitution'],
#  ['Department', 'source', 'told', 'Constitution', 'however'],
#  ['source', 'told', 'Constitution', 'however', 'Vandiver'],
#  ['told', 'Constitution', 'however', 'Vandiver', 'consulted'],
#  ['Constitution', 'however', 'Vandiver', 'consulted', 'yet'],
#  ['however', 'Vandiver', 'consulted', 'yet', 'plans'],
#  ['Vandiver', 'consulted', 'yet', 'plans', 'issue'],
#  ['consulted', 'yet', 'plans', 'issue', 'new'],
#  ['yet', 'plans', 'issue', 'new', 'rural'],
#  ['plans', 'issue', 'new', 'rural', 'roads'],
#  ['issue', 'new', 'rural', 'roads', 'bonds'],
#  ['new', 'rural', 'roads', 'bonds', 'Schley'],
#  ['rural', 'roads', 'bonds', 'Schley', 'County'],
#  ['roads', 'bonds', 'Schley', 'County', 'Rep'],
#  ['bonds', 'Schley', 'County', 'Rep', 'B'],
#  ['Schley', 'County', 'Rep', 'B', 'Pelham'],
#  ['County', 'Rep', 'B', 'Pelham', 'offer'],
#  ['Rep', 'B', 'Pelham', 'offer', 'resolution'],
#  ['B', 'Pelham', 'offer', 'resolution', 'Monday'],
#  ['Pelham', 'offer', 'resolution', 'Monday', 'House'],
#  ['offer', 'resolution', 'Monday', 'House', 'rescind'],
#  ['resolution', 'Monday', 'House', 'rescind', 'bodys'],
#  ['Monday', 'House', 'rescind', 'bodys', 'action'],
#  ['House', 'rescind', 'bodys', 'action', 'Friday'],
#  ['rescind', 'bodys', 'action', 'Friday', 'voting'],
#  ['bodys', 'action', 'Friday', 'voting', '$'],
#  ['action', 'Friday', 'voting', '$', 'per'],
#  ['Friday', 'voting', '$', 'per', 'day'],
#  ['voting', '$', 'per', 'day', 'increase'],
#  ['$', 'per', 'day', 'increase', 'expense'],
#  ['per', 'day', 'increase', 'expense', 'allowances'],
#  ['day', 'increase', 'expense', 'allowances', 'Pelham'],
#  ['increase', 'expense', 'allowances', 'Pelham', 'said'],
#  ['expense', 'allowances', 'Pelham', 'said', 'Sunday'],
#  ['allowances', 'Pelham', 'said', 'Sunday', 'night'],
#  ['Pelham', 'said', 'Sunday', 'night', 'research'],
#  ['said', 'Sunday', 'night', 'research', 'done'],
#  ['Sunday', 'night', 'research', 'done', 'whether'],
#  ['night', 'research', 'done', 'whether', 'quickie'],
#  ['research', 'done', 'whether', 'quickie', 'vote'],
#  ['done', 'whether', 'quickie', 'vote', 'increase'],
#  ['whether', 'quickie', 'vote', 'increase', 'repealed'],
#  ['quickie', 'vote', 'increase', 'repealed', 'outright'],
#  ['vote', 'increase', 'repealed', 'outright', 'whether'],
#  ['increase', 'repealed', 'outright', 'whether', 'notice'],
#  ['repealed', 'outright', 'whether', 'notice', 'would'],
#  ['outright', 'whether', 'notice', 'would', 'first'],
#  ['whether', 'notice', 'would', 'first', 'given'],
#  ['notice', 'would', 'first', 'given', 'reconsideration'],
#  ['would', 'first', 'given', 'reconsideration', 'action'],
#  ['first', 'given', 'reconsideration', 'action', 'would'],
#  ['given', 'reconsideration', 'action', 'would', 'sought'],
#  ['reconsideration', 'action', 'would', 'sought', 'emphasizing'],
#  ['action', 'would', 'sought', 'emphasizing', 'technical'],
#  ['would', 'sought', 'emphasizing', 'technical', 'details'],
#  ['sought', 'emphasizing', 'technical', 'details', 'fully'],
#  ['emphasizing', 'technical', 'details', 'fully', 'worked'],
#  ['technical', 'details', 'fully', 'worked', 'Pelham'],
#  ['details', 'fully', 'worked', 'Pelham', 'said'],
#  ['fully', 'worked', 'Pelham', 'said', 'resolution'],
#  ['worked', 'Pelham', 'said', 'resolution', 'would'],
#  ['Pelham', 'said', 'resolution', 'would', 'seek'],
#  ['said', 'resolution', 'would', 'seek', 'set'],
#  ['resolution', 'would', 'seek', 'set', 'aside'],
#  ['would', 'seek', 'set', 'aside', 'privilege'],
#  ['seek', 'set', 'aside', 'privilege', 'resolution'],
#  ['set', 'aside', 'privilege', 'resolution', 'House'],
#  ['aside', 'privilege', 'resolution', 'House', 'voted'],
#  ['privilege', 'resolution', 'House', 'voted', 'similar'],
#  ['resolution', 'House', 'voted', 'similar', 'resolution'],
#  ['House', 'voted', 'similar', 'resolution', 'passed'],
#  ['voted', 'similar', 'resolution', 'passed', 'Senate'],
#  ['similar', 'resolution', 'passed', 'Senate', 'vote'],
#  ['resolution', 'passed', 'Senate', 'vote', 'Sunday'],
#  ['passed', 'Senate', 'vote', 'Sunday', 'night'],
#  ['Senate', 'vote', 'Sunday', 'night', 'word'],
#  ['vote', 'Sunday', 'night', 'word', 'resolution'],
#  ['Sunday', 'night', 'word', 'resolution', 'offered'],
#  ['night', 'word', 'resolution', 'offered', 'rescind'],
#  ['word', 'resolution', 'offered', 'rescind', 'action'],
#  ['resolution', 'offered', 'rescind', 'action', 'Pelham'],
#  ['offered', 'rescind', 'action', 'Pelham', 'pointed'],
#  ['rescind', 'action', 'Pelham', 'pointed', 'Georgia'],
#  ['action', 'Pelham', 'pointed', 'Georgia', 'voters'],
#  ['Pelham', 'pointed', 'Georgia', 'voters', 'last'],
#  ['pointed', 'Georgia', 'voters', 'last', 'November'],
#  ['Georgia', 'voters', 'last', 'November', 'rejected'],
#  ['voters', 'last', 'November', 'rejected', 'constitutional'],
#  ['last', 'November', 'rejected', 'constitutional', 'amendment'],
#  ['November', 'rejected', 'constitutional', 'amendment', 'allow'],
#  ['rejected', 'constitutional', 'amendment', 'allow', 'legislators'],
#  ['constitutional', 'amendment', 'allow', 'legislators', 'vote'],
#  ['amendment', 'allow', 'legislators', 'vote', 'pay'],
#  ['allow', 'legislators', 'vote', 'pay', 'raises'],
#  ['legislators', 'vote', 'pay', 'raises', 'future'],
#  ['vote', 'pay', 'raises', 'future', 'Legislature'],
#  ['pay', 'raises', 'future', 'Legislature', 'sessions'],
#  ['raises', 'future', 'Legislature', 'sessions', 'veteran'],
#  ['future', 'Legislature', 'sessions', 'veteran', 'Jackson'],
#  ['Legislature', 'sessions', 'veteran', 'Jackson', 'County'],
#  ['sessions', 'veteran', 'Jackson', 'County', 'legislator'],
#  ['veteran', 'Jackson', 'County', 'legislator', 'ask'],
#  ['Jackson', 'County', 'legislator', 'ask', 'Georgia'],
#  ['County', 'legislator', 'ask', 'Georgia', 'House'],
#  ['legislator', 'ask', 'Georgia', 'House', 'Monday'],
#  ['ask', 'Georgia', 'House', 'Monday', 'back'],
#  ['Georgia', 'House', 'Monday', 'back', 'federal'],
#  ['House', 'Monday', 'back', 'federal', 'aid'],
#  ['Monday', 'back', 'federal', 'aid', 'education'],
#  ['back', 'federal', 'aid', 'education', 'something'],
#  ['federal', 'aid', 'education', 'something', 'consistently'],
#  ['aid', 'education', 'something', 'consistently', 'opposed'],
#  ['education', 'something', 'consistently', 'opposed', 'past'],
#  ['something', 'consistently', 'opposed', 'past', 'Rep'],
#  ['consistently', 'opposed', 'past', 'Rep', 'Mac'],
#  ['opposed', 'past', 'Rep', 'Mac', 'Barber'],
#  ['past', 'Rep', 'Mac', 'Barber', 'Commerce'],
#  ['Rep', 'Mac', 'Barber', 'Commerce', 'asking'],
#  ['Mac', 'Barber', 'Commerce', 'asking', 'House'],
#  ['Barber', 'Commerce', 'asking', 'House', 'privilege'],
#  ['Commerce', 'asking', 'House', 'privilege', 'resolution'],
#  ['asking', 'House', 'privilege', 'resolution', 'endorse'],
#  ['House', 'privilege', 'resolution', 'endorse', 'increased'],
#  ['privilege', 'resolution', 'endorse', 'increased', 'federal'],
#  ['resolution', 'endorse', 'increased', 'federal', 'support'],
#  ['endorse', 'increased', 'federal', 'support', 'public'],
#  ['increased', 'federal', 'support', 'public', 'education'],
#  ['federal', 'support', 'public', 'education', 'provided'],
#  ['support', 'public', 'education', 'provided', 'funds'],
#  ['public', 'education', 'provided', 'funds', 'received'],
#  ['education', 'provided', 'funds', 'received', 'expended'],
#  ['provided', 'funds', 'received', 'expended', 'state'],
#  ['funds', 'received', 'expended', 'state', 'funds'],
#  ['received', 'expended', 'state', 'funds', 'Barber'],
#  ['expended', 'state', 'funds', 'Barber', 'th'],
#  ['state', 'funds', 'Barber', 'th', 'year'],
#  ['funds', 'Barber', 'th', 'year', 'legislator'],
#  ['Barber', 'th', 'year', 'legislator', 'said'],
#  ['th', 'year', 'legislator', 'said', 'members'],
#  ['year', 'legislator', 'said', 'members', 'congressional'],
#  ['legislator', 'said', 'members', 'congressional', 'delegation'],
#  ['said', 'members', 'congressional', 'delegation', 'Washington'],
#  ['members', 'congressional', 'delegation', 'Washington', 'would'],
#  ['congressional', 'delegation', 'Washington', 'would', 'like'],
#  ['delegation', 'Washington', 'would', 'like', 'see'],
#  ['Washington', 'would', 'like', 'see', 'resolution'],
#  ['would', 'like', 'see', 'resolution', 'passed'],
#  ['like', 'see', 'resolution', 'passed', 'added'],
#  ['see', 'resolution', 'passed', 'added', 'none'],
#  ['resolution', 'passed', 'added', 'none', 'Georgias'],
#  ['passed', 'added', 'none', 'Georgias', 'congressmen'],
#  ['added', 'none', 'Georgias', 'congressmen', 'specifically'],
#  ['none', 'Georgias', 'congressmen', 'specifically', 'asked'],
#  ['Georgias', 'congressmen', 'specifically', 'asked', 'offer'],
#  ['congressmen', 'specifically', 'asked', 'offer', 'resolution'],
#  ['specifically', 'asked', 'offer', 'resolution', 'resolution'],
#  ['asked', 'offer', 'resolution', 'resolution', 'Barber'],
#  ['offer', 'resolution', 'resolution', 'Barber', 'tossed'],
#  ['resolution', 'resolution', 'Barber', 'tossed', 'House'],
#  ['resolution', 'Barber', 'tossed', 'House', 'hopper'],
#  ['Barber', 'tossed', 'House', 'hopper', 'Friday'],
#  ['tossed', 'House', 'hopper', 'Friday', 'formally'],
#  ['House', 'hopper', 'Friday', 'formally', 'read'],
#  ['hopper', 'Friday', 'formally', 'read', 'Monday'],
#  ['Friday', 'formally', 'read', 'Monday', 'says'],
#  ['formally', 'read', 'Monday', 'says', 'event'],
#  ['read', 'Monday', 'says', 'event', 'Congress'],
#  ['Monday', 'says', 'event', 'Congress', 'provide'],
#  ['says', 'event', 'Congress', 'provide', 'increase'],
#  ['event', 'Congress', 'provide', 'increase', 'federal'],
#  ['Congress', 'provide', 'increase', 'federal', 'funds'],
#  ['provide', 'increase', 'federal', 'funds', 'State'],
#  ['increase', 'federal', 'funds', 'State', 'Board'],
#  ['federal', 'funds', 'State', 'Board', 'Education'],
#  ['funds', 'State', 'Board', 'Education', 'directed'],
#  ['State', 'Board', 'Education', 'directed', 'give'],
#  ['Board', 'Education', 'directed', 'give', 'priority'],
#  ['Education', 'directed', 'give', 'priority', 'teacher'],
#  ['directed', 'give', 'priority', 'teacher', 'pay'],
#  ['give', 'priority', 'teacher', 'pay', 'raises'],
#  ['priority', 'teacher', 'pay', 'raises', 'Colquitt'],
#  ['teacher', 'pay', 'raises', 'Colquitt', 'long'],
#  ['pay', 'raises', 'Colquitt', 'long', 'hot'],
#  ['raises', 'Colquitt', 'long', 'hot', 'controversy'],
#  ['Colquitt', 'long', 'hot', 'controversy', 'Miller'],
#  ['long', 'hot', 'controversy', 'Miller', 'County'],
#  ['hot', 'controversy', 'Miller', 'County', 'new'],
#  ['controversy', 'Miller', 'County', 'new', 'school'],
#  ['Miller', 'County', 'new', 'school', 'superintendent'],
#  ...]
